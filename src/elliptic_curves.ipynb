# %% [markdown]
# # Curvas elípticas

# %%
E =  EllipticCurve(RR, [1, 0]);
plot(E, (-2, 4), color=hue(0.8))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
E =  EllipticCurve(RR, [-1, 0]);
plot(E, (-4, 3), color=hue(0.6))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
E = EllipticCurve('37a')
@interact
def f(p=primes(2,500)):
    show(plot(E.change_ring(GF(p)),pointsize=30),
    axes=False, frame=True, gridlines="automatic",
    aspect_ratio=1)
# Out:
# SW50ZXJhY3RpdmUgZnVuY3Rpb24gPGZ1bmN0aW9uIGYgYXQgMHg3ZjFlMjM0M2RkNzA+IHdpdGggMSB3aWRnZXQKICBwOiBTZWxlY3Rpb25TbGlkZXIoZGVzY3JpcHRpb249dSdwJywgb3B0aW/igKY=

# %%
def f(p=primes(2,500)):
    show(plot(E.change_ring(GF(p)),pointsize=30),
    axes=False, frame=True, gridlines="automatic",
    aspect_ratio=1, gridlinesstyle={'rgbcolor':(0.7,0.7,0.7)})

# %%
f(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-2e89c032841f> in <module>()
# ----> 1 f(Integer(5))
#
# <ipython-input-15-76132a63164b> in f(p)
#       2     show(plot(E.change_ring(GF(p)),pointsize=Integer(30)),
#       3     axes=False, frame=True, gridlines="automatic",
# ----> 4     aspect_ratio=Integer(1), gridlinesstyle={'rgbcolor':(RealNumber('0.7'),RealNumber('0.7'),RealNumber('0.7'))})
#
# /mnt/2CECC21EECC1E1E6/SageMath/local/lib/python2.7/site-packages/sage/repl/rich_output/pretty_print.pyc in show(*args, **kwds)
#     256         args[0].show()
#     257         return
# --> 258     pretty_print(*args, **kwds)
#
# /mnt/2CECC21EECC1E1E6/SageMath/local/lib/python2.7/site-packages/sage/repl/rich_output/pretty_print.pyc in pretty_print(*args, **kwds)
#     227             pass
#     228         elif len(args) == 1:
# ...
