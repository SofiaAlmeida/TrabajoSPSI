# %% [markdown]
# # Curvas elípticas

# %%
E =  EllipticCurve(RR, [1, 0]);
plot(E, (-2, 4), color=hue(0.8))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
E =  EllipticCurve(RR, [-1, 0]);
plot(E, (-4, 3), color=hue(0.6))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
E = EllipticCurve('37a')
@interact
def f(p=primes(2,500)):
    show(plot(E.change_ring(GF(p)),pointsize=30),
    axes=False, frame=True, gridlines="automatic",
    aspect_ratio=1)
# Out:
# SW50ZXJhY3RpdmUgZnVuY3Rpb24gPGZ1bmN0aW9uIGYgYXQgMHg3ZjEzMjE3MzVlNjA+IHdpdGggMSB3aWRnZXQKICBwOiBTZWxlY3Rpb25TbGlkZXIoZGVzY3JpcHRpb249dSdwJywgb3B0aW/igKY=
